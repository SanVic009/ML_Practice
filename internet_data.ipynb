# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets/worldbank-country-internet-data.csv')

# %%
df.sample(10)
# Out:
#                     Country Name Country Code  \
# 1048                     Vanuatu          VUT
# 1236  Middle East & North Africa          MEA
# 556                      Lesotho          LSO
# 505                        Kenya          KEN
# 291             Egypt, Arab Rep.          EGY
# 719                        Niger          NER
# 716                        Niger          NER
# 1068          West Bank and Gaza          PSE
# 1201   Latin America & Caribbean          LCN
# 474                  Isle of Man          IMN
#
#                                             Series Name        Series Code  \
# 1048                            Secure Internet servers        IT.NET.SECR
# 1236  Individuals using the Internet, female (% of f...  IT.NET.USER.FE.ZS
# 556   Individuals using the Internet, female (% of f...  IT.NET.USER.FE.ZS
# 505    Individuals using the Internet (% of population)     IT.NET.USER.ZS
# 291   Individuals using the Internet, female (% of f...  IT.NET.USER.FE.ZS
# ...

# %%
df['Series Name'].unique()
# Out:
# array(['Individuals using the Internet (% of population)',
#        'Individuals using the Internet, female (% of female population)',
#        'Individuals using the Internet, male (% of male population)',
#        'Secure Internet servers',
#        'Secure Internet servers (per 1 million people)', nan],
#       dtype=object)
